# %%
import numpy as np
import matplotlib.pyplot as plt

# %matplotlib inline

mass_of_star = 1.0 
rp = 1.0 #AU (astronomical unit)
vp = 35.0 #km/s
MassOfSun = 2e33 #g
MassOfJupiter = 1.898e30 #g
AUinCM = 1.496e13 #AU in CM
kmincm = 1e5 #cm/km
G = 6.674e-8 # gravitational constant in cm^3 g^-1 s^-2
mass_of_star = mass_of_star * MassOfSun
vp = vp*kmincm
rp = rp*AUinCM

# %%
#mStar is in g, rStar is a 2D vector representing 
# distance from planet to star with (x,y) components (in cm)
def calcAcc(m2, r1, r2, x):
    #mag(r)=sqrt(r_x^2 + r_y^2)
    mag_r=((r1[0]-r2[0])**2 + (r1[1]-r2[1])**2)**0.5
    #acc due to gravity: a = -G*M/mag_r^x
    mag_a=-G*m2/mag_r**x
    #direction = planet is being pulled back towards the sun
    unitVector=(r1-r2)/mag_r
    acc=mag_a*unitVector
    return acc

# %%
#initial conditions
mass_of_particle1 = 0.0009 #Msun
rp = 1.0 #AU
vp = 35.0 #km/s

mass_of_particle1 = mass_of_particle1*MassOfSun
vp = vp*kmincm
rp = rp*AUinCM

# %%
mass_of_particle2 = 1 #Msun = Mass jupiter
mass_of_particle2 = mass_of_particle2*MassOfSun

# %%
r_0 = np.array([[rp, 0], [0, 0]])
v_0 = np.array([[0, vp], [0, 0]])

# %% [markdown]
# # When x = 2

# %%
#r = np.array([]) WRONG!
r=[]
ri = r_0 # initial starting radius
vi = v_0 # initial starting velocity
for i in range(n_step): # for 50 steps
    #1. calculate acceleration of gravity at a particular position when x=2
    ag_particle1 = calcAcc(mass_of_particle2, ri[0,:], ri[1,:], 2)
    ag_particle2 = calcAcc(mass_of_particle1, ri[1,:], ri[0,:], 2)
    #format the acceleration vector
    ag = np.array([ag_particle1, ag_particle2])
    #2. update velocity based on this acceleration 
    vip1 = vi + ag*delta_t
    #3. update position from new or old velocity
    rip1 = ri + vi*delta_t
    
    #bookkeeping
    #1. save our new radius
    #r = np.append(r, rip1) WRONG!
    r.append(rip1)
    #2. update "initial" conditions for next loop
    ri = rip1
    vi = vip1
    
r=np.array(r)
r.shape
# Out:
# (500000, 2, 2)

# %%
plt.plot(r[:,0,0]/AUinCM, r[:,0,1]/AUinCM)
plt.plot(r[:,1,0]/AUinCM, r[:,1,1]/AUinCM)
plt.show()

# %% [markdown]
# # When x = 3

# %%
#r = np.array([]) WRONG!
r=[]
ri = r_0 # initial starting radius
vi = v_0 # initial starting velocity
for i in range(n_step): # for 50 steps
    #1. calculate acceleration of gravity at a particular position when x=3
    ag_particle1 = calcAcc(mass_of_particle2, ri[0,:], ri[1,:], 3)
    ag_particle2 = calcAcc(mass_of_particle1, ri[1,:], ri[0,:], 3)
    #format the acceleration vector
    ag = np.array([ag_particle1, ag_particle2])
    #2. update velocity based on this acceleration 
    vip1 = vi + ag*delta_t
    #3. update position from new or old velocity
    rip1 = ri + vi*delta_t
    
    #bookkeeping
    #1. save our new radius
    #r = np.append(r, rip1) WRONG!
    r.append(rip1)
    #2. update "initial" conditions for next loop
    ri = rip1
    vi = vip1
    
r=np.array(r)
r.shape
# Out:
# (500000, 2, 2)

# %%
plt.plot(r[:,0,0]/AUinCM, r[:,0,1]/AUinCM)
plt.plot(r[:,1,0]/AUinCM, r[:,1,1]/AUinCM)
plt.show()

# %% [markdown]
# # When x = 1.9

# %%
#r = np.array([]) WRONG!
r=[]
ri = r_0 # initial starting radius
vi = v_0 # initial starting velocity
for i in range(n_step): # for 50 steps
    #1. calculate acceleration of gravity at a particular position when x=1.9
    ag_particle1 = calcAcc(mass_of_particle2, ri[0,:], ri[1,:], 1.9)
    ag_particle2 = calcAcc(mass_of_particle1, ri[1,:], ri[0,:], 1.9)
    #format the acceleration vector
    ag = np.array([ag_particle1, ag_particle2])
    #2. update velocity based on this acceleration 
    vip1 = vi + ag*delta_t
    #3. update position from new or old velocity
    rip1 = ri + vi*delta_t
    
    #bookkeeping
    #1. save our new radius
    #r = np.append(r, rip1) WRONG!
    r.append(rip1)
    #2. update "initial" conditions for next loop
    ri = rip1
    vi = vip1
    
r=np.array(r)
r.shape
# Out:
# (500000, 2, 2)

# %%
plt.plot(r[:,0,0]/AUinCM, r[:,0,1]/AUinCM)
plt.plot(r[:,1,0]/AUinCM, r[:,1,1]/AUinCM)
plt.show()

# %% [markdown]
# # When x = 2.1

# %%
#r = np.array([]) WRONG!
r=[]
ri = r_0 # initial starting radius
vi = v_0 # initial starting velocity
for i in range(n_step): # for 50 steps
    #1. calculate acceleration of gravity at a particular position when x=2.1
    ag_particle1 = calcAcc(mass_of_particle2, ri[0,:], ri[1,:], 2.1)
    ag_particle2 = calcAcc(mass_of_particle1, ri[1,:], ri[0,:], 2.1)
    #format the acceleration vector
    ag = np.array([ag_particle1, ag_particle2])
    #2. update velocity based on this acceleration 
    vip1 = vi + ag*delta_t
    #3. update position from new or old velocity
    rip1 = ri + vi*delta_t
    
    #bookkeeping
    #1. save our new radius
    #r = np.append(r, rip1) WRONG!
    r.append(rip1)
    #2. update "initial" conditions for next loop
    ri = rip1
    vi = vip1
    
r=np.array(r)
r.shape
# Out:
# (500000, 2, 2)

# %%
plt.plot(r[:,0,0]/AUinCM, r[:,0,1]/AUinCM)
plt.plot(r[:,1,0]/AUinCM, r[:,1,1]/AUinCM)
plt.show()

# %% [markdown]
# # EXTRA CREDIT TASK

# %%
#mStar is in g, rStar is a 2D vector representing 
# distance from planet to star with (x,y) components (in cm)
def calcAcc1(m2, r1, r2, C):
    #mag(r)=sqrt(r_x^2 + r_y^2)
    mag_r=((r1[0]-r2[0])**2 + (r1[1]-r2[1])**2)**0.5
    #acc due to gravity: a = -G*M/mag_r^x
    mag_a=(-G*m2/mag_r**2)-C*(G*m2/mag_r**4)
    #direction = planet is being pulled back towards the sun
    unitVector=(r1-r2)/mag_r
    acc=mag_a*unitVector
    return acc

# %% [markdown]
# # When C = 1e25

# %%
r=[]
ri = r_0 # initial starting radius
vi = v_0 # initial starting velocity
for i in range(n_step): # for 50 steps
    #1. calculate acceleration of gravity at a particular position
    ag_particle1 = calcAcc1(mass_of_particle2, ri[0,:], ri[1,:], 1e25)
    ag_particle2 = calcAcc1(mass_of_particle1, ri[1,:], ri[0,:], 1e25)
    #format the acceleration vector
    ag = np.array([ag_particle1, ag_particle2])
    #2. update velocity based on this acceleration 
    vip1 = vi + ag*delta_t
    #3. update position from new or old velocity
    rip1 = ri + vi*delta_t
    
    #bookkeeping
    #1. save our new radius
    #r = np.append(r, rip1) WRONG!
    r.append(rip1)
    #2. update "initial" conditions for next loop
    ri = rip1
    vi = vip1
    
r=np.array(r)
r.shape
# Out:
# (500000, 2, 2)

# %%
plt.plot(r[:,0,0]/AUinCM, r[:,0,1]/AUinCM)
plt.plot(r[:,1,0]/AUinCM, r[:,1,1]/AUinCM)
plt.show()

# %% [markdown]
# # When C = 1e35

# %%
r=[]
ri = r_0 # initial starting radius
vi = v_0 # initial starting velocity
for i in range(n_step): # for 50 steps
    #1. calculate acceleration of gravity at a particular position
    ag_particle1 = calcAcc1(mass_of_particle2, ri[0,:], ri[1,:], 1e35)
    ag_particle2 = calcAcc1(mass_of_particle1, ri[1,:], ri[0,:], 1e35)
    #format the acceleration vector
    ag = np.array([ag_particle1, ag_particle2])
    #2. update velocity based on this acceleration 
    vip1 = vi + ag*delta_t
    #3. update position from new or old velocity
    rip1 = ri + vi*delta_t
    
    #bookkeeping
    #1. save our new radius
    #r = np.append(r, rip1) WRONG!
    r.append(rip1)
    #2. update "initial" conditions for next loop
    ri = rip1
    vi = vip1
    
r=np.array(r)
r.shape
# Out:
# (500000, 2, 2)

# %%
plt.plot(r[:,0,0]/AUinCM, r[:,0,1]/AUinCM)
plt.plot(r[:,1,0]/AUinCM, r[:,1,1]/AUinCM)
plt.show()
